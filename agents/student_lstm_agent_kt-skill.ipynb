# %%
import pandas as pd

# Read the cleaned dataset
df = pd.read_csv('../data/cleaned_df.csv')
df.head()
# Out:
#    user_id  order_id  correct answer_type  attempt_count  hint_count  \
# 0    77912  20223948      1.0     algebra              1           0
# 1    77912  20223955      1.0    choose_1              1           0
# 2    77912  20223963      1.0    choose_1              1           0
# 3    77912  20223971      1.0    choose_1              1           0
# 4    77912  20223984      1.0    choose_1              1           0
#
#    overlap_time                                   skill_name_split
# 0         95637  ['Effect of Changing Dimensions of a Shape Pro...
# 1        227226  ['Effect of Changing Dimensions of a Shape Pro...
# 2        165891  ['Effect of Changing Dimensions of a Shape Pro...
# 3        129112  ['Effect of Changing Dimensions of a Shape Pro...
# 4         87127                         ['Addition Whole Numbers']

# %%
user_counts = df['user_id'].value_counts()
max_freq = user_counts.max()
min_freq = user_counts.min()
avg_freq = user_counts.mean()
print(f"Max frequency of user_id: {max_freq}")
print(f"Min frequency of user_id: {min_freq}")
print(f"Avg frequency of user_id: {avg_freq:.2f}")
# Out:
# Max frequency of user_id: 1036
# Min frequency of user_id: 10
# Avg frequency of user_id: 87.96

# %%
df.shape
# Out:
# (549020, 8)

# %%
# Now sort by user_id and order_id
df = df.sort_values(['user_id', 'order_id'])
df.head()
# Out:
#         user_id  order_id  correct answer_type  attempt_count  hint_count  \
# 450658    26787  34955672      1.0     algebra              1           0
# 450659    26787  34955681      1.0     algebra              1           0
# 450660    26787  34955693      1.0     algebra              1           0
# 450661    26787  34955702      1.0     algebra              1           0
# 450662    26787  34955716      1.0     algebra              1           0
#
#         overlap_time                            skill_name_split
# 450658         12044                               ['Unit Rate']
# 450659          3728                ['Interior Angles Triangle']
# 450660          4241  ['Complementary and Supplementary Angles']
# 450661          4161                                   ['Table']
# 450662          7674       ['Calculations with Similar Figures']

# %%
# One-hot encode the 'answer_type' column for df, outputting 1/0 (default for get_dummies)
answer_type_ohe = pd.get_dummies(df['answer_type'], prefix='answer_type', dtype=int)

# Concatenate the one-hot encoded columns to df
df = pd.concat([df, answer_type_ohe], axis=1)

df.head()
# Out:
#         user_id  order_id  correct answer_type  attempt_count  hint_count  \
# 450658    26787  34955672      1.0     algebra              1           0
# 450659    26787  34955681      1.0     algebra              1           0
# 450660    26787  34955693      1.0     algebra              1           0
# 450661    26787  34955702      1.0     algebra              1           0
# 450662    26787  34955716      1.0     algebra              1           0
#
#         overlap_time                            skill_name_split  \
# 450658         12044                               ['Unit Rate']
# 450659          3728                ['Interior Angles Triangle']
# 450660          4241  ['Complementary and Supplementary Angles']
# 450661          4161                                   ['Table']
# 450662          7674       ['Calculations with Similar Figures']
#
#         answer_type_algebra  answer_type_choose_1  answer_type_fill_in_1
# 450658                    1                     0                      0
# 450659                    1                     0                      0
# 450660                    1                     0                      0
# 450661                    1                     0                      0
# 450662                    1                     0                      0

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale 'overlap_time', 'hint_count', and 'attempt_count' in df using MinMaxScaler
scaler = MinMaxScaler()
for col in ['overlap_time', 'hint_count', 'attempt_count']:
    if col in df.columns:
        df[col] = scaler.fit_transform(df[[col]])

df[['overlap_time', 'hint_count', 'attempt_count']].head()
# Out:
#         overlap_time  hint_count  attempt_count
# 450658      0.003549         0.0       0.000419
# 450659      0.003539         0.0       0.000419
# 450660      0.003540         0.0       0.000419
# 450661      0.003540         0.0       0.000419
# 450662      0.003544         0.0       0.000419

# %% [markdown]
# Prepare Sequences

# %%
# 1. Get all unique skills from all arrays in 'skill_name_split'
all_skills = [
  "* () positive reals",
  "-",
  "/",
  "Absolute Value",
  "Addition Whole Numbers",
  "Addition and Subtraction Fractions",
  "Addition and Subtraction Integers",
  "Addition and Subtraction Positive Decimals",
  "Algebraic Simplification",
  "Algebraic Solving",
  "Angles - Acute",
  "Angles - Obtuse",
  "Angles - Right",
  "Angles on Parallel Lines Cut by a Transversal",
  "Area Circle",
  "Area Irregular Figure",
  "Area Parallelogram",
  "Area Rectangle",
  "Area Trapezoid",
  "Area Triangle",
  "Box and Whisker",
  "Calculation with + - * /",
  "Calculations with Similar Figures",
  "Choose an Equation from Given Information",
  "Circle Graph",
  "Circumference",
  "Coefficient",
  "Combinatorics",
  "Combining Like Terms",
  "Commutative Property",
  "Complementary and Supplementary Angles",
  "Composition of Function Adding",
  "Compound Interest",
  "Computation with Real Numbers",
  "Congruence",
  "Conversion of Fraction Decimals Percents",
  "Counting Methods",
  "Definition Pi",
  "Distributive Property",
  "Divisibility Rules",
  "Division Fractions",
  "Division Whole Numbers",
  "Effect of Changing Dimensions of a Shape Proportionally",
  "English and Metric Terminology",
  "Equal As Balance Concept",
  "Equation Solving More Than Two Steps",
  "Equation Solving Two or Fewer Steps",
  "Equivalent Fractions",
  "Estimation",
  "Expanded",
  "Exponent",
  "Exponents",
  "Factoring Trinomials",
  "Finding Max and Min from a Quadratic Equation",
  "Finding Percents",
  "Finding Ratios",
  "Finding Slope From Equation",
  "Finding Slope From Situation",
  "Finding Slope from Graph",
  "Finding Slope from Ordered Pairs",
  "Finding fractions and ratios",
  "Finding y-intercept from Linear Equation",
  "Finding y-intercept from Linear Situation",
  "Fraction Of",
  "Geometric Definitions",
  "Graph Shape",
  "Graphing Inequalities on a number line",
  "Greatest Common Factor",
  "Histogram as Table or Graph",
  "Intercept",
  "Interior Angles Figures with More than 3 Sides",
  "Interior Angles Triangle",
  "Inverse Relations",
  "Least Common Multiple",
  "Line Plot",
  "Line Symmetry",
  "Line of Best-Fit",
  "Linear Equations",
  "Linear area volume conversion",
  "Mean",
  "Mean-Median-Mode-Range Differentiation",
  "Median",
  "Mode",
  "Monomial",
  "Multiplication Fractions",
  "Multiplication Whole Numbers",
  "Multiplication and Division Integers",
  "Multiplication and Division Positive Decimals",
  "Multiplying Monomials",
  "Multiplying non Monomial Polynomials",
  "Nets of 3D Figures",
  "Number Line",
  "Order of Operations",
  "Order of Operations All",
  "Ordering Fractions",
  "Ordering Integers",
  "Ordering Positive Decimals",
  "Ordering Real Numbers",
  "Ordering Whole Numbers",
  "Parallel and Perpendicular Lines",
  "Parallel and Perpendicular Slopes",
  "Parts of a Polyomial",
  "Pattern Finding",
  "Percent Discount",
  "Percent Increase or Decrease",
  "Percent Of",
  "Percents",
  "Perimeter of a Polygon",
  "Picking Equation and Inequality from Choices",
  "Point Plotting",
  "Polynomial Factors",
  "Prime Number",
  "Probability of Two Distinct Events",
  "Probability of a Single Event",
  "Properties and Classification Quadrilaterals",
  "Properties and Classification Rectangular Prisms",
  "Properties and Classification Triangles",
  "Properties of Numbers",
  "Proportion",
  "Pythagorean Theorem",
  "Quadratic Equation Solving",
  "Range",
  "Rate",
  "Reading a Ruler or Scale",
  "Recognize Linear Pattern",
  "Recognizing Equivalent Expressions",
  "Reflection",
  "Rotations",
  "Rounding",
  "Sampling Techniques",
  "Scale Factor",
  "Scatter Plot",
  "Scientific Notation",
  "Similar Figures",
  "Simplifying Expressions positive exponents",
  "Slope",
  "Solve Quadratic Equations Using Factoring",
  "Solving Inequalities",
  "Solving System of Equation",
  "Solving Systems of Linear Equations",
  "Solving for a variable",
  "Square Root",
  "Square Roots",
  "Standard and Word Notation",
  "Stem and Leaf Plot",
  "Substitution",
  "Subtraction Whole Numbers",
  "Surface Area Cylinder",
  "Surface Area Rectangular Prism",
  "Surface Area Sphere",
  "Surface Area of 3D Objects",
  "Symbolization",
  "Table",
  "Terms",
  "Transformation",
  "Translations",
  "Understanding Concept of Probabilities",
  "Unit Conversion Standard to Metric",
  "Unit Conversion Within a System",
  "Unit Rate",
  "Variable",
  "Venn Diagram",
  "Volume Cone",
  "Volume Cylinder",
  "Volume Prism",
  "Volume Pyramid",
  "Volume Rectangular Prism",
  "Volume Sphere",
  "Volume of 3D Objects",
  "Write Linear Equation from Graph",
  "Write Linear Equation from Ordered Pairs",
  "Write Linear Equation from Situation",
  "Writing Expression from Diagrams",
  "X-Y Graph Reading"
]
skill2id = {skill: idx for idx, skill in enumerate(all_skills)}

# 2. Map each skill array to an array of skill_ids
df['skill_ids'] = df['skill_name_split'].apply(lambda skills: [skill2id[s] for s in skills if s in skill2id])

num_skills = len(all_skills)
print(f"Number of unique skills: {num_skills}")

# 3. Create question_type_id
df['question_type_id'] = pd.Categorical(df['answer_type']).codes
num_question_types = df['question_type_id'].nunique()
print(f"Number of unique question types: {num_question_types}")
# Out:
# Number of unique skills: 174
# Number of unique question types: 3

# %%
import ast

# Convert string representation of list to actual list
if isinstance(df['skill_name_split'].iloc[0], str):
    df['skill_name_split'] = df['skill_name_split'].apply(ast.literal_eval)

# Now this will work as intended:
df['skill_ids'] = df['skill_name_split'].apply(lambda skills: [skill2id[s] for s in skills if s in skill2id])

# %%
# Show the tail of (skill_ids, skill_name_split, question_type_id, answer_type) pairings
print(df[['skill_ids', 'skill_name_split', 'question_type_id', 'answer_type']].tail(20))
# Out:
#        skill_ids                                 skill_name_split  \
# 535982     [119]                            [Pythagorean Theorem]
# 535983       [5]             [Addition and Subtraction Fractions]
# 535984     [119]                            [Pythagorean Theorem]
# 535985     [145]                                   [Substitution]
# 535986      [87]  [Multiplication and Division Positive Decimals]
# 535987     [119]                            [Pythagorean Theorem]
# 535988     [119]                            [Pythagorean Theorem]
# 535989     [119]                            [Pythagorean Theorem]
# 535990     [119]                            [Pythagorean Theorem]
# 535991     [119]                            [Pythagorean Theorem]
# 535992     [109]                                 [Point Plotting]
# 535993     [119]                            [Pythagorean Theorem]
# 535994     [145]                                   [Substitution]
# 535995      [87]  [Multiplication and Division Positive Decimals]
# 535996     [119]                            [Pythagorean Theorem]
# 535997     [119]                            [Pythagorean Theorem]
# 535998     [119]                            [Pythagorean Theorem]
# 535999     [119]                            [Pythagorean Theorem]
# 536000      [41]                         [Division Whole Numbers]
# 536001      [41]                         [Division Whole Numbers]
#
#         question_type_id answer_type
# 535982                 1    choose_1
# 535983                 1    choose_1
# 535984                 1    choose_1
# 535985                 1    choose_1
# 535986                 1    choose_1
# 535987                 1    choose_1
# 535988                 0     algebra
# 535989                 0     algebra
# 535990                 0     algebra
# 535991                 0     algebra
# 535992                 0     algebra
# 535993                 0     algebra
# 535994                 0     algebra
# 535995                 0     algebra
# 535996                 2   fill_in_1
# 535997                 2   fill_in_1
# 535998                 0     algebra
# 535999                 0     algebra
# 536000                 2   fill_in_1
# 536001                 0     algebra

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

def prepare_dkt_sequences(df, num_skills=num_skills, max_seq_len=50, 
                          extra_features_cols=['attempt_count', 'hint_count', 'overlap_time']):
    """
    Prepares student interaction sequences for DKT-style LSTM input.
    Handles multiple skills per sample by encoding each skill separately.
    """
    input_seqs = []
    output_seqs = []
    extras = []

    grouped = df.sort_values('order_id').groupby('user_id')

    for _, group in grouped:
        x_seq = []
        y_seq = []
        extras_seq = []

        skill_ids_list = group['skill_ids'].values
        corrects = group['correct'].values
        extra_features = group[extra_features_cols].iloc[1:].values.tolist() if extra_features_cols else None

        for i in range(len(skill_ids_list) - 1):
            skills = skill_ids_list[i]
            correct = int(corrects[i] > 0.5)
            next_skills = skill_ids_list[i+1]
            next_correct = corrects[i+1]

            for skill in skills:
                x_encoded = skill + correct * num_skills 
                x_seq.append(x_encoded)

            y_vec = np.zeros(num_skills)
            for next_skill in next_skills:
                y_vec[next_skill-1] = next_correct
            y_seq.append(y_vec)

            if extra_features_cols:
                extras_seq.append(extra_features[i] if i < len(extra_features) else [0]*len(extra_features_cols))

        # Split long sequences into chunks of max_seq_len
        for start in range(0, len(x_seq), max_seq_len):
            end = start + max_seq_len
            input_seqs.append(x_seq[start:end])
            output_seqs.append(y_seq[start:end])
            if extra_features_cols:
                extras.append(extras_seq[start:end])

    X_input = pad_sequences(input_seqs, padding='post', maxlen=max_seq_len)
    Y_output = pad_sequences(output_seqs, padding='post', maxlen=max_seq_len, dtype='float32')

    extra_inputs = None
    if extra_features_cols:
        extra_inputs = pad_sequences(extras, padding='post', maxlen=max_seq_len, dtype='float32')

    # Pad all sequences
    X_input = pad_sequences(input_seqs, padding='post', maxlen=max_seq_len)
    Y_output = pad_sequences(output_seqs, padding='post', maxlen=max_seq_len, dtype='float32')

    # Handle extra features
    extra_inputs = None
    if extra_features_cols:
        extra_inputs = pad_sequences(extras, padding='post', maxlen=max_seq_len, dtype='float32')

    # Print encoding distribution for debug
    import collections
    all_encodings = [enc for seq in input_seqs for enc in seq]
    encoding_counts = collections.Counter(all_encodings)
    print(f"\nTop 20 most common input encodings (skill+correct):")
    for k, v in encoding_counts.most_common(20):
        print(f"Encoding {k}: {v} times")
    print(f"\nLeast 20 input encodings (skill+correct):")
    for k, v in encoding_counts.most_common()[-20:]:
        print(f"Encoding {k}: {v} times")
    print(f"Total unique input encodings: {len(encoding_counts)}")

    return X_input, Y_output, extra_inputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from tensorflow.keras.preprocessing.sequence import pad_sequences
#       2 import numpy as np
#       4 def prepare_dkt_sequences(df, num_skills=num_skills, max_seq_len=50,
#       5                           extra_features_cols=['attempt_count', 'hint_count', 'overlap_time']):
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#      97 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, TimeDistributed
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Constant
from tensorflow.keras.callbacks import EarlyStopping

def build_dkt_model(
    num_skills=num_skills,
    num_extra_features=3,
    embedding_dim=32,
    lstm_units=80,
    use_bilstm=True,
    dropout_rate=0.3,
    learning_rate=0.002,
    pretrained_skill_embeddings=None, 
    trainable=False,
    use_extra_input=True
):
    num_total_inputs = num_skills * 2  

    # Inputs
    skill_input = Input(shape=(None,), name='skill_input')
    inputs = [skill_input]

    if pretrained_skill_embeddings is not None:
        skill_embed = Embedding(
            input_dim=num_total_inputs,
            output_dim=embedding_dim,
            embeddings_initializer=Constant(pretrained_skill_embeddings),
            trainable=trainable,
            name='pretrained_skill_embedding'
        )(skill_input)
    else:
        skill_embed = Embedding(
            input_dim=num_total_inputs,
            output_dim=embedding_dim,
            name='skill_embedding'
        )(skill_input)

    if use_extra_input:
        extra_input = Input(shape=(None, num_extra_features), name='extra_input')
        inputs.append(extra_input)
        merged_input = Concatenate(name='concat_inputs')([skill_embed, extra_input])
    else:
        merged_input = skill_embed

    merged_input = Dropout(dropout_rate)(merged_input)

    if use_bilstm:
        lstm_out = Bidirectional(
            LSTM(units=lstm_units, return_sequences=True, dropout=dropout_rate),
            name='bilstm_layer'
        )(merged_input)
    else:
        lstm_out = LSTM(units=lstm_units, return_sequences=True, dropout=dropout_rate, name='lstm_layer')(merged_input)

    predictions = TimeDistributed(Dense(num_skills, activation='sigmoid'), name='predictions')(lstm_out)

    optimizer = Adam(learning_rate=learning_rate)
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC', 'Accuracy', 'Precision', 'Recall'])

    return model

# %%
X, y, extras = prepare_dkt_sequences(df, max_seq_len=50)
# Out:
# Top 20 most common input encodings (skill+correct):
# Encoding 276: 16015 times
# Encoding 292: 12974 times
# Encoding 180: 10736 times
# Encoding 102: 10653 times
# Encoding 118: 9553 times
# Encoding 319: 9444 times
# Encoding 287: 8823 times
# Encoding 261: 8519 times
# Encoding 326: 8490 times
# Encoding 239: 8182 times
# Encoding 113: 7614 times
# Encoding 228: 6910 times
# Encoding 333: 6834 times
# Encoding 6: 6806 times
# Encoding 152: 6569 times
# Encoding 145: 6512 times
# Encoding 65: 6484 times
# Encoding 293: 6284 times
# Encoding 87: 6204 times
# Encoding 221: 6134 times
#
# Least 20 input encodings (skill+correct):
# Encoding 64: 19 times
# Encoding 44: 19 times
# Encoding 238: 18 times
# Encoding 254: 17 times
# Encoding 240: 15 times
# Encoding 80: 14 times
# Encoding 75: 13 times
# Encoding 135: 13 times
# Encoding 66: 12 times
# Encoding 77: 12 times
# Encoding 69: 10 times
# Encoding 167: 9 times
# Encoding 284: 7 times
# Encoding 165: 7 times
# Encoding 53: 7 times
# Encoding 249: 5 times
# Encoding 323: 5 times
# Encoding 110: 4 times
# Encoding 201: 3 times
# Encoding 27: 3 times
# Total unique input encodings: 341

# %%
X.shape
# Out:
# (14100, 50)

# %%
y.shape
# Out:
# (14100, 50, 174)

# %%
extras.shape
# Out:
# (14100, 50, 3)

# %%
from sklearn.model_selection import train_test_split

# Split into train and validation sets (80/20 split)
X_train, X_val, y_train, y_val, extras_train, extras_val = train_test_split(
    X, y, extras, test_size=0.25, random_state=42
)

print(f"Train shapes: X={X_train.shape}, y={y_train.shape}, extras={extras_train.shape}")
print(f"Validation shapes: X={X_val.shape}, y={y_val.shape}, extras={extras_val.shape}")
# Out:
# Train shapes: X=(10575, 50), y=(10575, 50, 174), extras=(10575, 50, 3)
# Validation shapes: X=(3525, 50), y=(3525, 50, 174), extras=(3525, 50, 3)

# %% [markdown]
# Main student agent

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title("Loss over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Binary Crossentropy")
    plt.legend()

    # AUC
    plt.subplot(1, 2, 2)
    plt.plot(history.history['AUC'], label='Train AUC')
    plt.plot(history.history['val_AUC'], label='Val AUC')
    plt.title("AUC over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("AUC")
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Create text embedding for DKT

# %%
df['correct'] = (df['correct'] > 0.5).astype(int)

# Build skill_texts for all possible input encodings (for embedding matrix)
skill_texts = []
question_type_names = list(df['answer_type'].astype(str).unique())
for skill_id in range(num_skills):
    for correct in [0, 1]:
        skill_name = all_skills[skill_id]
        skill_texts.append(f"Skill: {skill_name}, Correct: {correct}")

skill_texts
# Out:
# ['Skill: * () positive reals, Correct: 0',
#  'Skill: * () positive reals, Correct: 1',
#  'Skill: -, Correct: 0',
#  'Skill: -, Correct: 1',
#  'Skill: /, Correct: 0',
#  'Skill: /, Correct: 1',
#  'Skill: Absolute Value, Correct: 0',
#  'Skill: Absolute Value, Correct: 1',
#  'Skill: Addition Whole Numbers, Correct: 0',
#  'Skill: Addition Whole Numbers, Correct: 1',
#  'Skill: Addition and Subtraction Fractions, Correct: 0',
#  'Skill: Addition and Subtraction Fractions, Correct: 1',
#  'Skill: Addition and Subtraction Integers, Correct: 0',
#  'Skill: Addition and Subtraction Integers, Correct: 1',
#  'Skill: Addition and Subtraction Positive Decimals, Correct: 0',
#  'Skill: Addition and Subtraction Positive Decimals, Correct: 1',
#  'Skill: Algebraic Simplification, Correct: 0',
#  'Skill: Algebraic Simplification, Correct: 1',
#  'Skill: Algebraic Solving, Correct: 0',
#  'Skill: Algebraic Solving, Correct: 1',
#  'Skill: Angles - Acute, Correct: 0',
#  'Skill: Angles - Acute, Correct: 1',
#  'Skill: Angles - Obtuse, Correct: 0',
#  'Skill: Angles - Obtuse, Correct: 1',
#  'Skill: Angles - Right, Correct: 0',
#  'Skill: Angles - Right, Correct: 1',
#  'Skill: Angles on Parallel Lines Cut by a Transversal, Correct: 0',
#  'Skill: Angles on Parallel Lines Cut by a Transversal, Correct: 1',
#  'Skill: Area Circle, Correct: 0',
#  'Skill: Area Circle, Correct: 1',
#  'Skill: Area Irregular Figure, Correct: 0',
#  'Skill: Area Irregular Figure, Correct: 1',
#  'Skill: Area Parallelogram, Correct: 0',
#  'Skill: Area Parallelogram, Correct: 1',
#  'Skill: Area Rectangle, Correct: 0',
#  'Skill: Area Rectangle, Correct: 1',
#  'Skill: Area Trapezoid, Correct: 0',
#  'Skill: Area Trapezoid, Correct: 1',
#  'Skill: Area Triangle, Correct: 0',
#  'Skill: Area Triangle, Correct: 1',
#  'Skill: Box and Whisker, Correct: 0',
#  'Skill: Box and Whisker, Correct: 1',
#  'Skill: Calculation with + - * /, Correct: 0',
#  'Skill: Calculation with + - * /, Correct: 1',
#  'Skill: Calculations with Similar Figures, Correct: 0',
#  'Skill: Calculations with Similar Figures, Correct: 1',
#  'Skill: Choose an Equation from Given Information, Correct: 0',
#  'Skill: Choose an Equation from Given Information, Correct: 1',
#  'Skill: Circle Graph, Correct: 0',
#  'Skill: Circle Graph, Correct: 1',
#  'Skill: Circumference, Correct: 0',
#  'Skill: Circumference, Correct: 1',
#  'Skill: Coefficient, Correct: 0',
#  'Skill: Coefficient, Correct: 1',
#  'Skill: Combinatorics, Correct: 0',
#  'Skill: Combinatorics, Correct: 1',
#  'Skill: Combining Like Terms, Correct: 0',
#  'Skill: Combining Like Terms, Correct: 1',
#  'Skill: Commutative Property, Correct: 0',
#  'Skill: Commutative Property, Correct: 1',
#  'Skill: Complementary and Supplementary Angles, Correct: 0',
#  'Skill: Complementary and Supplementary Angles, Correct: 1',
#  'Skill: Composition of Function Adding, Correct: 0',
#  'Skill: Composition of Function Adding, Correct: 1',
#  'Skill: Compound Interest, Correct: 0',
#  'Skill: Compound Interest, Correct: 1',
#  'Skill: Computation with Real Numbers, Correct: 0',
#  'Skill: Computation with Real Numbers, Correct: 1',
#  'Skill: Congruence, Correct: 0',
#  'Skill: Congruence, Correct: 1',
#  'Skill: Conversion of Fraction Decimals Percents, Correct: 0',
#  'Skill: Conversion of Fraction Decimals Percents, Correct: 1',
#  'Skill: Counting Methods, Correct: 0',
#  'Skill: Counting Methods, Correct: 1',
#  'Skill: Definition Pi, Correct: 0',
#  'Skill: Definition Pi, Correct: 1',
#  'Skill: Distributive Property, Correct: 0',
#  'Skill: Distributive Property, Correct: 1',
#  'Skill: Divisibility Rules, Correct: 0',
#  'Skill: Divisibility Rules, Correct: 1',
#  'Skill: Division Fractions, Correct: 0',
#  'Skill: Division Fractions, Correct: 1',
#  'Skill: Division Whole Numbers, Correct: 0',
#  'Skill: Division Whole Numbers, Correct: 1',
#  'Skill: Effect of Changing Dimensions of a Shape Proportionally, Correct: 0',
#  'Skill: Effect of Changing Dimensions of a Shape Proportionally, Correct: 1',
#  'Skill: English and Metric Terminology, Correct: 0',
#  'Skill: English and Metric Terminology, Correct: 1',
#  'Skill: Equal As Balance Concept, Correct: 0',
#  'Skill: Equal As Balance Concept, Correct: 1',
#  'Skill: Equation Solving More Than Two Steps, Correct: 0',
#  'Skill: Equation Solving More Than Two Steps, Correct: 1',
#  'Skill: Equation Solving Two or Fewer Steps, Correct: 0',
#  'Skill: Equation Solving Two or Fewer Steps, Correct: 1',
#  'Skill: Equivalent Fractions, Correct: 0',
#  'Skill: Equivalent Fractions, Correct: 1',
#  'Skill: Estimation, Correct: 0',
#  'Skill: Estimation, Correct: 1',
#  'Skill: Expanded, Correct: 0',
#  'Skill: Expanded, Correct: 1',
#  'Skill: Exponent, Correct: 0',
#  'Skill: Exponent, Correct: 1',
#  'Skill: Exponents, Correct: 0',
#  'Skill: Exponents, Correct: 1',
#  'Skill: Factoring Trinomials, Correct: 0',
#  'Skill: Factoring Trinomials, Correct: 1',
#  'Skill: Finding Max and Min from a Quadratic Equation, Correct: 0',
#  'Skill: Finding Max and Min from a Quadratic Equation, Correct: 1',
#  'Skill: Finding Percents, Correct: 0',
#  'Skill: Finding Percents, Correct: 1',
#  'Skill: Finding Ratios, Correct: 0',
#  'Skill: Finding Ratios, Correct: 1',
#  'Skill: Finding Slope From Equation, Correct: 0',
#  'Skill: Finding Slope From Equation, Correct: 1',
#  'Skill: Finding Slope From Situation, Correct: 0',
#  'Skill: Finding Slope From Situation, Correct: 1',
#  'Skill: Finding Slope from Graph, Correct: 0',
#  'Skill: Finding Slope from Graph, Correct: 1',
#  'Skill: Finding Slope from Ordered Pairs, Correct: 0',
#  'Skill: Finding Slope from Ordered Pairs, Correct: 1',
#  'Skill: Finding fractions and ratios, Correct: 0',
#  'Skill: Finding fractions and ratios, Correct: 1',
#  'Skill: Finding y-intercept from Linear Equation, Correct: 0',
#  'Skill: Finding y-intercept from Linear Equation, Correct: 1',
#  'Skill: Finding y-intercept from Linear Situation, Correct: 0',
#  'Skill: Finding y-intercept from Linear Situation, Correct: 1',
#  'Skill: Fraction Of, Correct: 0',
#  'Skill: Fraction Of, Correct: 1',
#  'Skill: Geometric Definitions, Correct: 0',
#  'Skill: Geometric Definitions, Correct: 1',
#  'Skill: Graph Shape, Correct: 0',
#  'Skill: Graph Shape, Correct: 1',
#  'Skill: Graphing Inequalities on a number line, Correct: 0',
#  'Skill: Graphing Inequalities on a number line, Correct: 1',
#  'Skill: Greatest Common Factor, Correct: 0',
#  'Skill: Greatest Common Factor, Correct: 1',
#  'Skill: Histogram as Table or Graph, Correct: 0',
#  'Skill: Histogram as Table or Graph, Correct: 1',
#  'Skill: Intercept, Correct: 0',
#  'Skill: Intercept, Correct: 1',
#  'Skill: Interior Angles Figures with More than 3 Sides, Correct: 0',
#  'Skill: Interior Angles Figures with More than 3 Sides, Correct: 1',
#  'Skill: Interior Angles Triangle, Correct: 0',
#  'Skill: Interior Angles Triangle, Correct: 1',
#  'Skill: Inverse Relations, Correct: 0',
#  'Skill: Inverse Relations, Correct: 1',
#  'Skill: Least Common Multiple, Correct: 0',
#  'Skill: Least Common Multiple, Correct: 1',
#  'Skill: Line Plot, Correct: 0',
#  'Skill: Line Plot, Correct: 1',
#  'Skill: Line Symmetry, Correct: 0',
#  'Skill: Line Symmetry, Correct: 1',
#  'Skill: Line of Best-Fit, Correct: 0',
#  'Skill: Line of Best-Fit, Correct: 1',
#  'Skill: Linear Equations, Correct: 0',
#  'Skill: Linear Equations, Correct: 1',
#  'Skill: Linear area volume conversion, Correct: 0',
#  'Skill: Linear area volume conversion, Correct: 1',
#  'Skill: Mean, Correct: 0',
#  'Skill: Mean, Correct: 1',
#  'Skill: Mean-Median-Mode-Range Differentiation, Correct: 0',
#  'Skill: Mean-Median-Mode-Range Differentiation, Correct: 1',
#  'Skill: Median, Correct: 0',
#  'Skill: Median, Correct: 1',
#  'Skill: Mode, Correct: 0',
#  'Skill: Mode, Correct: 1',
#  'Skill: Monomial, Correct: 0',
#  'Skill: Monomial, Correct: 1',
#  'Skill: Multiplication Fractions, Correct: 0',
#  'Skill: Multiplication Fractions, Correct: 1',
#  'Skill: Multiplication Whole Numbers, Correct: 0',
#  'Skill: Multiplication Whole Numbers, Correct: 1',
#  'Skill: Multiplication and Division Integers, Correct: 0',
#  'Skill: Multiplication and Division Integers, Correct: 1',
#  'Skill: Multiplication and Division Positive Decimals, Correct: 0',
#  'Skill: Multiplication and Division Positive Decimals, Correct: 1',
#  'Skill: Multiplying Monomials, Correct: 0',
#  'Skill: Multiplying Monomials, Correct: 1',
#  'Skill: Multiplying non Monomial Polynomials, Correct: 0',
#  'Skill: Multiplying non Monomial Polynomials, Correct: 1',
#  'Skill: Nets of 3D Figures, Correct: 0',
#  'Skill: Nets of 3D Figures, Correct: 1',
#  'Skill: Number Line, Correct: 0',
#  'Skill: Number Line, Correct: 1',
#  'Skill: Order of Operations, Correct: 0',
#  'Skill: Order of Operations, Correct: 1',
#  'Skill: Order of Operations All, Correct: 0',
#  'Skill: Order of Operations All, Correct: 1',
#  'Skill: Ordering Fractions, Correct: 0',
#  'Skill: Ordering Fractions, Correct: 1',
#  'Skill: Ordering Integers, Correct: 0',
#  'Skill: Ordering Integers, Correct: 1',
#  'Skill: Ordering Positive Decimals, Correct: 0',
#  'Skill: Ordering Positive Decimals, Correct: 1',
#  'Skill: Ordering Real Numbers, Correct: 0',
#  'Skill: Ordering Real Numbers, Correct: 1',
#  'Skill: Ordering Whole Numbers, Correct: 0',
#  'Skill: Ordering Whole Numbers, Correct: 1',
#  'Skill: Parallel and Perpendicular Lines, Correct: 0',
#  'Skill: Parallel and Perpendicular Lines, Correct: 1',
#  'Skill: Parallel and Perpendicular Slopes, Correct: 0',
#  'Skill: Parallel and Perpendicular Slopes, Correct: 1',
#  'Skill: Parts of a Polyomial, Correct: 0',
#  'Skill: Parts of a Polyomial, Correct: 1',
#  'Skill: Pattern Finding, Correct: 0',
#  'Skill: Pattern Finding, Correct: 1',
#  'Skill: Percent Discount, Correct: 0',
#  'Skill: Percent Discount, Correct: 1',
#  'Skill: Percent Increase or Decrease, Correct: 0',
#  'Skill: Percent Increase or Decrease, Correct: 1',
#  'Skill: Percent Of, Correct: 0',
#  'Skill: Percent Of, Correct: 1',
#  'Skill: Percents, Correct: 0',
#  'Skill: Percents, Correct: 1',
#  'Skill: Perimeter of a Polygon, Correct: 0',
#  'Skill: Perimeter of a Polygon, Correct: 1',
#  'Skill: Picking Equation and Inequality from Choices, Correct: 0',
#  'Skill: Picking Equation and Inequality from Choices, Correct: 1',
#  'Skill: Point Plotting, Correct: 0',
#  'Skill: Point Plotting, Correct: 1',
#  'Skill: Polynomial Factors, Correct: 0',
#  'Skill: Polynomial Factors, Correct: 1',
#  'Skill: Prime Number, Correct: 0',
#  'Skill: Prime Number, Correct: 1',
#  'Skill: Probability of Two Distinct Events, Correct: 0',
#  'Skill: Probability of Two Distinct Events, Correct: 1',
#  'Skill: Probability of a Single Event, Correct: 0',
#  'Skill: Probability of a Single Event, Correct: 1',
#  'Skill: Properties and Classification Quadrilaterals, Correct: 0',
#  'Skill: Properties and Classification Quadrilaterals, Correct: 1',
#  'Skill: Properties and Classification Rectangular Prisms, Correct: 0',
#  'Skill: Properties and Classification Rectangular Prisms, Correct: 1',
#  'Skill: Properties and Classification Triangles, Correct: 0',
#  'Skill: Properties and Classification Triangles, Correct: 1',
#  'Skill: Properties of Numbers, Correct: 0',
#  'Skill: Properties of Numbers, Correct: 1',
#  'Skill: Proportion, Correct: 0',
#  'Skill: Proportion, Correct: 1',
#  'Skill: Pythagorean Theorem, Correct: 0',
#  'Skill: Pythagorean Theorem, Correct: 1',
#  'Skill: Quadratic Equation Solving, Correct: 0',
#  'Skill: Quadratic Equation Solving, Correct: 1',
#  'Skill: Range, Correct: 0',
#  'Skill: Range, Correct: 1',
#  'Skill: Rate, Correct: 0',
#  'Skill: Rate, Correct: 1',
#  'Skill: Reading a Ruler or Scale, Correct: 0',
#  'Skill: Reading a Ruler or Scale, Correct: 1',
#  'Skill: Recognize Linear Pattern, Correct: 0',
#  'Skill: Recognize Linear Pattern, Correct: 1',
#  'Skill: Recognizing Equivalent Expressions, Correct: 0',
#  'Skill: Recognizing Equivalent Expressions, Correct: 1',
#  'Skill: Reflection, Correct: 0',
#  'Skill: Reflection, Correct: 1',
#  'Skill: Rotations, Correct: 0',
#  'Skill: Rotations, Correct: 1',
#  'Skill: Rounding, Correct: 0',
#  'Skill: Rounding, Correct: 1',
#  'Skill: Sampling Techniques, Correct: 0',
#  'Skill: Sampling Techniques, Correct: 1',
#  'Skill: Scale Factor, Correct: 0',
#  'Skill: Scale Factor, Correct: 1',
#  'Skill: Scatter Plot, Correct: 0',
#  'Skill: Scatter Plot, Correct: 1',
#  'Skill: Scientific Notation, Correct: 0',
#  'Skill: Scientific Notation, Correct: 1',
#  'Skill: Similar Figures, Correct: 0',
#  'Skill: Similar Figures, Correct: 1',
#  'Skill: Simplifying Expressions positive exponents, Correct: 0',
#  'Skill: Simplifying Expressions positive exponents, Correct: 1',
#  'Skill: Slope, Correct: 0',
#  'Skill: Slope, Correct: 1',
#  'Skill: Solve Quadratic Equations Using Factoring, Correct: 0',
#  'Skill: Solve Quadratic Equations Using Factoring, Correct: 1',
#  'Skill: Solving Inequalities, Correct: 0',
#  'Skill: Solving Inequalities, Correct: 1',
#  'Skill: Solving System of Equation, Correct: 0',
#  'Skill: Solving System of Equation, Correct: 1',
#  'Skill: Solving Systems of Linear Equations, Correct: 0',
#  'Skill: Solving Systems of Linear Equations, Correct: 1',
#  'Skill: Solving for a variable, Correct: 0',
#  'Skill: Solving for a variable, Correct: 1',
#  'Skill: Square Root, Correct: 0',
#  'Skill: Square Root, Correct: 1',
#  'Skill: Square Roots, Correct: 0',
#  'Skill: Square Roots, Correct: 1',
#  'Skill: Standard and Word Notation, Correct: 0',
#  'Skill: Standard and Word Notation, Correct: 1',
#  'Skill: Stem and Leaf Plot, Correct: 0',
#  'Skill: Stem and Leaf Plot, Correct: 1',
#  'Skill: Substitution, Correct: 0',
#  'Skill: Substitution, Correct: 1',
#  'Skill: Subtraction Whole Numbers, Correct: 0',
#  'Skill: Subtraction Whole Numbers, Correct: 1',
#  'Skill: Surface Area Cylinder, Correct: 0',
#  'Skill: Surface Area Cylinder, Correct: 1',
#  'Skill: Surface Area Rectangular Prism, Correct: 0',
#  'Skill: Surface Area Rectangular Prism, Correct: 1',
#  'Skill: Surface Area Sphere, Correct: 0',
#  'Skill: Surface Area Sphere, Correct: 1',
#  'Skill: Surface Area of 3D Objects, Correct: 0',
#  'Skill: Surface Area of 3D Objects, Correct: 1',
#  'Skill: Symbolization, Correct: 0',
#  'Skill: Symbolization, Correct: 1',
#  'Skill: Table, Correct: 0',
#  'Skill: Table, Correct: 1',
#  'Skill: Terms, Correct: 0',
#  'Skill: Terms, Correct: 1',
#  'Skill: Transformation, Correct: 0',
#  'Skill: Transformation, Correct: 1',
#  'Skill: Translations, Correct: 0',
#  'Skill: Translations, Correct: 1',
#  'Skill: Understanding Concept of Probabilities, Correct: 0',
#  'Skill: Understanding Concept of Probabilities, Correct: 1',
#  'Skill: Unit Conversion Standard to Metric, Correct: 0',
#  'Skill: Unit Conversion Standard to Metric, Correct: 1',
#  'Skill: Unit Conversion Within a System, Correct: 0',
#  'Skill: Unit Conversion Within a System, Correct: 1',
#  'Skill: Unit Rate, Correct: 0',
#  'Skill: Unit Rate, Correct: 1',
#  'Skill: Variable, Correct: 0',
#  'Skill: Variable, Correct: 1',
#  'Skill: Venn Diagram, Correct: 0',
#  'Skill: Venn Diagram, Correct: 1',
#  'Skill: Volume Cone, Correct: 0',
#  'Skill: Volume Cone, Correct: 1',
#  'Skill: Volume Cylinder, Correct: 0',
#  'Skill: Volume Cylinder, Correct: 1',
#  'Skill: Volume Prism, Correct: 0',
#  'Skill: Volume Prism, Correct: 1',
#  'Skill: Volume Pyramid, Correct: 0',
#  'Skill: Volume Pyramid, Correct: 1',
#  'Skill: Volume Rectangular Prism, Correct: 0',
#  'Skill: Volume Rectangular Prism, Correct: 1',
#  'Skill: Volume Sphere, Correct: 0',
#  'Skill: Volume Sphere, Correct: 1',
#  'Skill: Volume of 3D Objects, Correct: 0',
#  'Skill: Volume of 3D Objects, Correct: 1',
#  'Skill: Write Linear Equation from Graph, Correct: 0',
#  'Skill: Write Linear Equation from Graph, Correct: 1',
#  'Skill: Write Linear Equation from Ordered Pairs, Correct: 0',
#  'Skill: Write Linear Equation from Ordered Pairs, Correct: 1',
#  'Skill: Write Linear Equation from Situation, Correct: 0',
#  'Skill: Write Linear Equation from Situation, Correct: 1',
#  'Skill: Writing Expression from Diagrams, Correct: 0',
#  'Skill: Writing Expression from Diagrams, Correct: 1',
#  'Skill: X-Y Graph Reading, Correct: 0',
#  'Skill: X-Y Graph Reading, Correct: 1']

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# Load transformer model and tokenizer
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
model.eval()

def get_embeddings(texts, batch_size=32):
    all_embeddings = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        with torch.no_grad():
            encoded_input = tokenizer(batch, padding=True, truncation=True, return_tensors="pt")
            model_output = model(**encoded_input)
            embeddings = model_output.last_hidden_state.mean(dim=1)
            all_embeddings.append(embeddings.cpu().numpy())
    return np.vstack(all_embeddings)

pretrained_skill_embeddings = get_embeddings(skill_texts)
print("pretrained_skill_embeddings shape:", pretrained_skill_embeddings.shape)
# Out:
# pretrained_skill_embeddings shape: (348, 384)

# %% [markdown]
# Trainable Text Embeddings

# %%
trainable_text_emb_dkt_model = build_dkt_model(
    embedding_dim=pretrained_skill_embeddings.shape[1],
    pretrained_skill_embeddings=pretrained_skill_embeddings,
    lstm_units=128, use_bilstm=True, learning_rate=0.002, trainable=True, use_extra_input=False
)
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True, min_delta=0.0002)
history = trainable_text_emb_dkt_model.fit(
    x={'skill_input': X_train},
    y=y_train,
    batch_size=32,
    epochs=15, 
    validation_data=({'skill_input': X_val,}, y_val),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - AUC: 0.5604 - accuracy: 0.0115 - loss: 0.1070 - val_AUC: 0.7273 - val_accuracy: 0.0184 - val_loss: 0.0143
# Epoch 2/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - AUC: 0.7318 - accuracy: 0.0163 - loss: 0.0139 - val_AUC: 0.7518 - val_accuracy: 0.0162 - val_loss: 0.0140
# Epoch 3/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - AUC: 0.7601 - accuracy: 0.0191 - loss: 0.0138 - val_AUC: 0.7694 - val_accuracy: 0.0304 - val_loss: 0.0136
# Epoch 4/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - AUC: 0.7881 - accuracy: 0.0286 - loss: 0.0135 - val_AUC: 0.8123 - val_accuracy: 0.0415 - val_loss: 0.0129
# Epoch 5/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - AUC: 0.8174 - accuracy: 0.0422 - loss: 0.0126 - val_AUC: 0.8440 - val_accuracy: 0.0547 - val_loss: 0.0121
# Epoch 6/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - AUC: 0.8487 - accuracy: 0.0524 - loss: 0.0117 - val_AUC: 0.8645 - val_accuracy: 0.0740 - val_loss: 0.0110
# Epoch 7/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - AUC: 0.8705 - accuracy: 0.0797 - loss: 0.0107 - val_AUC: 0.8867 - val_accuracy: 0.1032 - val_loss: 0.0100
# Epoch 8/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - AUC: 0.8952 - accuracy: 0.1165 - loss: 0.0096 - val_AUC: 0.9169 - val_accuracy: 0.1468 - val_loss: 0.0089
# Epoch 9/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - AUC: 0.9210 - accuracy: 0.1531 - loss: 0.0085 - val_AUC: 0.9361 - val_accuracy: 0.1914 - val_loss: 0.0077
# Epoch 10/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - AUC: 0.9389 - accuracy: 0.1972 - loss: 0.0075 - val_AUC: 0.9487 - val_accuracy: 0.2375 - val_loss: 0.0067
# Epoch 11/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - AUC: 0.9497 - accuracy: 0.2389 - loss: 0.0066 - val_AUC: 0.9571 - val_accuracy: 0.2677 - val_loss: 0.0058
# Epoch 12/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - AUC: 0.9575 - accuracy: 0.2739 - loss: 0.0057 - val_AUC: 0.9620 - val_accuracy: 0.3009 - val_loss: 0.0050
# Epoch 13/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - AUC: 0.9629 - accuracy: 0.3015 - loss: 0.0049 - val_AUC: 0.9665 - val_accuracy: 0.3199 - val_loss: 0.0043
# Epoch 14/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - AUC: 0.9689 - accuracy: 0.3179 - loss: 0.0042 - val_AUC: 0.9705 - val_accuracy: 0.3350 - val_loss: 0.0037
# Epoch 15/15
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - AUC: 0.9715 - accuracy: 0.3317 - loss: 0.0037 - val_AUC: 0.9740 - val_accuracy: 0.3413 - val_loss: 0.0033

# %%
plot_history(history)

# %%
from itertools import product

embedding_dims = [64, 128]
lstm_units_list = [64, 128]
bilstm_options = [True]
batch_sizes = [16, 32]
use_extra_input_options = [False] # Since we won't simulate student agent's time spent, hint used, attempt count to keeep it simple
embedding_type_options = ['standard', 'pretrained']
dropout_rate_options = [0.2, 0.3]
trainable_options = [True]
learning_rate_options = [0.0025, 0.002] 

results = []
tried_configs = set()

for emb_type, emb_dim, lstm_units, use_bilstm, batch_size, use_extra_input, dropout_rate, trainable, learning_rate in product(
    embedding_type_options, embedding_dims, lstm_units_list, bilstm_options, batch_sizes, use_extra_input_options, dropout_rate_options, trainable_options, learning_rate_options
):
    # Only use trainable option for pretrained embeddings, standard always trainable
    if emb_type == 'pretrained':
        emb_dim = pretrained_skill_embeddings.shape[1]
        pretrained_emb = pretrained_skill_embeddings
        trainable_flag = trainable
    else:
        pretrained_emb = None
        trainable_flag = True  # Standard embedding should always be trainable

    # Build a tuple of the config to avoid repeats
    config_tuple = (
        emb_type, emb_dim, lstm_units, use_bilstm, batch_size, use_extra_input, dropout_rate, trainable_flag, learning_rate
    )
    if config_tuple in tried_configs:
        continue
    tried_configs.add(config_tuple)

    print(f"\nTraining with embedding_type={emb_type}, embedding_dim={emb_dim}, lstm_units={lstm_units}, use_bilstm={use_bilstm}, batch_size={batch_size}, use_extra_input={use_extra_input}, dropout_rate={dropout_rate}, trainable={trainable_flag}, learning_rate={learning_rate}")
    model = build_dkt_model(
        num_skills=num_skills,
        num_extra_features=3,
        num_question_types=num_question_types,
        embedding_dim=emb_dim,
        lstm_units=lstm_units,
        use_bilstm=use_bilstm,
        use_extra_input=use_extra_input,
        pretrained_skill_embeddings=pretrained_emb,
        dropout_rate=dropout_rate,
        trainable=trainable_flag,
        learning_rate=learning_rate
    )
    early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

    if use_extra_input:
        fit_inputs = {'skill_input': X_train, 'extra_input': extras_train}
        val_inputs = {'skill_input': X_val, 'extra_input': extras_val}
    else:
        fit_inputs = {'skill_input': X_train}
        val_inputs = {'skill_input': X_val}

    history = model.fit(
        x=fit_inputs,
        y=y_train,
        batch_size=batch_size,
        epochs=5,  # Used fewer epochs for quick test
        validation_data=(val_inputs, y_val),
        callbacks=[early_stop],
        verbose=0
    )
    
    best_val_auc = max(history.history['val_AUC'])
    best_val_acc = max(history.history['val_Accuracy'])
    best_val_precision = max(history.history['val_Precision'])
    best_val_recall = max(history.history['val_Recall'])
    print(f"Best val_AUC: {best_val_auc:.4f}")
    print(f"Best val_accuracy: {best_val_acc:.4f}")
    print(f"Best val_precision: {best_val_precision:.4f}")
    print(f"Best val_recall: {best_val_recall:.4f}")

    results.append({
        'embedding_type': emb_type,
        'embedding_dim': emb_dim,
        'lstm_units': lstm_units,
        'use_bilstm': use_bilstm,
        'batch_size': batch_size,
        'use_extra_input': use_extra_input,
        'dropout_rate': dropout_rate,
        'trainable': trainable_flag,
        'learning_rate': learning_rate,
        'best_val_auc': best_val_auc,
        'best_val_accuracy': best_val_acc,
        'best_val_precision': best_val_precision,
        'best_val_recall': best_val_recall,
        'history': history  # Store history for plotting
    })
# Out:
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8071
# Best val_accuracy: 0.0197
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7764
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7739
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7730
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7579
# Best val_accuracy: 0.0165
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7521
# Best val_accuracy: 0.0189
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7618
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7423
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7800
# Best val_accuracy: 0.0229
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8385
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8164
# Best val_accuracy: 0.0213
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8010
# Best val_accuracy: 0.0191
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7664
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7613
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7602
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=64, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7464
# Best val_accuracy: 0.0184
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8474
# Best val_accuracy: 0.0245
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8492
# Best val_accuracy: 0.0184
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8501
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8562
# Best val_accuracy: 0.0188
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7661
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7570
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7686
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7536
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8613
# Best val_accuracy: 0.0414
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8406
# Best val_accuracy: 0.0260
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8541
# Best val_accuracy: 0.0270
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8503
# Best val_accuracy: 0.0331
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7765
# Best val_accuracy: 0.0186
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7835
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7603
# Best val_accuracy: 0.0185
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=standard, embedding_dim=128, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7719
# Best val_accuracy: 0.0185
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.9105
# Best val_accuracy: 0.0792
# Best val_precision: 1.0000
# Best val_recall: 0.0001
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8897
# Best val_accuracy: 0.0724
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.9225
# Best val_accuracy: 0.1124
# Best val_precision: 0.9545
# Best val_recall: 0.0401
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.9013
# Best val_accuracy: 0.0663
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7750
# Best val_accuracy: 0.0192
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7640
# Best val_accuracy: 0.0199
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.7994
# Best val_accuracy: 0.0211
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=64, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.7638
# Best val_accuracy: 0.0187
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.9482
# Best val_accuracy: 0.1970
# Best val_precision: 0.9930
# Best val_recall: 0.1835
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.9372
# Best val_accuracy: 0.1928
# Best val_precision: 0.9599
# Best val_recall: 0.1781
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.9461
# Best val_accuracy: 0.2104
# Best val_precision: 1.0000
# Best val_recall: 0.2329
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=16, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.9408
# Best val_accuracy: 0.2093
# Best val_precision: 0.9742
# Best val_recall: 0.1931
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8089
# Best val_accuracy: 0.0291
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.2, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8421
# Best val_accuracy: 0.0515
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.0025
# Best val_AUC: 0.8711
# Best val_accuracy: 0.0590
# Best val_precision: 0.0000
# Best val_recall: 0.0000
#
# Training with embedding_type=pretrained, embedding_dim=384, lstm_units=128, use_bilstm=True, batch_size=32, use_extra_input=False, dropout_rate=0.3, trainable=True, learning_rate=0.002
# Best val_AUC: 0.8255
# Best val_accuracy: 0.0230
# Best val_precision: 0.0000
# Best val_recall: 0.0000

# %%
# Show sorted results
results = sorted(results, key=lambda x: x['best_val_auc'], reverse=True)
print("\nTop grid search results:")
for r in results[:5]:  # Show top 5
    print({k: v for k, v in r.items() if k != 'history'})

# Example: plot the history of the best run
best_history = results[0]['history']
plot_history(best_history)
# Out:
# Top grid search results:
# {'embedding_type': 'pretrained', 'embedding_dim': 384, 'lstm_units': 128, 'use_bilstm': True, 'batch_size': 16, 'use_extra_input': False, 'dropout_rate': 0.2, 'trainable': True, 'learning_rate': 0.0025, 'best_val_auc': 0.9482298493385315, 'best_val_accuracy': 0.19698913395404816, 'best_val_precision': 0.9929577708244324, 'best_val_recall': 0.1834796816110611}
# {'embedding_type': 'pretrained', 'embedding_dim': 384, 'lstm_units': 128, 'use_bilstm': True, 'batch_size': 16, 'use_extra_input': False, 'dropout_rate': 0.3, 'trainable': True, 'learning_rate': 0.0025, 'best_val_auc': 0.9461361169815063, 'best_val_accuracy': 0.2103779911994934, 'best_val_precision': 1.0, 'best_val_recall': 0.23287804424762726}
# {'embedding_type': 'pretrained', 'embedding_dim': 384, 'lstm_units': 128, 'use_bilstm': True, 'batch_size': 16, 'use_extra_input': False, 'dropout_rate': 0.3, 'trainable': True, 'learning_rate': 0.002, 'best_val_auc': 0.9407541751861572, 'best_val_accuracy': 0.20934012532234192, 'best_val_precision': 0.9742411971092224, 'best_val_recall': 0.19310569763183594}
# {'embedding_type': 'pretrained', 'embedding_dim': 384, 'lstm_units': 128, 'use_bilstm': True, 'batch_size': 16, 'use_extra_input': False, 'dropout_rate': 0.2, 'trainable': True, 'learning_rate': 0.002, 'best_val_auc': 0.9371986389160156, 'best_val_accuracy': 0.19276106357574463, 'best_val_precision': 0.9598647952079773, 'best_val_recall': 0.17808130383491516}
# {'embedding_type': 'pretrained', 'embedding_dim': 384, 'lstm_units': 64, 'use_bilstm': True, 'batch_size': 16, 'use_extra_input': False, 'dropout_rate': 0.3, 'trainable': True, 'learning_rate': 0.0025, 'best_val_auc': 0.9224914908409119, 'best_val_accuracy': 0.11236386746168137, 'best_val_precision': 0.9545454382896423, 'best_val_recall': 0.04009756073355675}

# %%
model = build_dkt_model(
    num_skills=num_skills,
    num_extra_features=3,
    embedding_dim=384,
    lstm_units=128,
    use_bilstm=True,
    use_extra_input=False,
    pretrained_skill_embeddings=pretrained_skill_embeddings,
    dropout_rate=0.2,
    trainable=True,
    learning_rate=0.0025
)
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
fit_inputs = {'skill_input': X_train}
val_inputs = {'skill_input': X_val}

history = model.fit(
    x=fit_inputs,
    y=y_train,
    batch_size=16,
    epochs=12,
    validation_data=(val_inputs, y_val),
    callbacks=[early_stop],
    verbose=1
)

plot_history(history)
# Out:
# Epoch 1/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 36s 41ms/step - AUC: 0.6920 - Accuracy: 0.0291 - Precision: 0.0035 - Recall: 0.0081 - loss: 0.0392 - val_AUC: 0.8859 - val_Accuracy: 0.1512 - val_Precision: 0.9852 - val_Recall: 0.0401 - val_loss: 0.0112
# Epoch 2/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9097 - Accuracy: 0.2020 - Precision: 0.9667 - Recall: 0.1340 - loss: 0.0096 - val_AUC: 0.9596 - val_Accuracy: 0.3497 - val_Precision: 0.9890 - val_Recall: 0.4974 - val_loss: 0.0053
# Epoch 3/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - AUC: 0.9624 - Accuracy: 0.3682 - Precision: 0.9874 - Recall: 0.5801 - loss: 0.0046 - val_AUC: 0.9790 - val_Accuracy: 0.4032 - val_Precision: 0.9915 - val_Recall: 0.8190 - val_loss: 0.0026
# Epoch 4/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - AUC: 0.9797 - Accuracy: 0.4075 - Precision: 0.9887 - Recall: 0.8339 - loss: 0.0025 - val_AUC: 0.9849 - val_Accuracy: 0.4163 - val_Precision: 0.9914 - val_Recall: 0.9030 - val_loss: 0.0017
# Epoch 5/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9848 - Accuracy: 0.4179 - Precision: 0.9875 - Recall: 0.9011 - loss: 0.0017 - val_AUC: 0.9883 - val_Accuracy: 0.4227 - val_Precision: 0.9915 - val_Recall: 0.9337 - val_loss: 0.0012
# Epoch 6/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9881 - Accuracy: 0.4256 - Precision: 0.9882 - Recall: 0.9296 - loss: 0.0013 - val_AUC: 0.9903 - val_Accuracy: 0.4255 - val_Precision: 0.9912 - val_Recall: 0.9470 - val_loss: 0.0010
# Epoch 7/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - AUC: 0.9895 - Accuracy: 0.4282 - Precision: 0.9876 - Recall: 0.9427 - loss: 0.0011 - val_AUC: 0.9912 - val_Accuracy: 0.4270 - val_Precision: 0.9913 - val_Recall: 0.9546 - val_loss: 8.9365e-04
# Epoch 8/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9904 - Accuracy: 0.4259 - Precision: 0.9865 - Recall: 0.9493 - loss: 0.0010 - val_AUC: 0.9916 - val_Accuracy: 0.4275 - val_Precision: 0.9908 - val_Recall: 0.9586 - val_loss: 8.3899e-04
# Epoch 9/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9919 - Accuracy: 0.4281 - Precision: 0.9872 - Recall: 0.9554 - loss: 9.0403e-04 - val_AUC: 0.9919 - val_Accuracy: 0.4277 - val_Precision: 0.9911 - val_Recall: 0.9621 - val_loss: 7.8302e-04
# Epoch 10/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - AUC: 0.9913 - Accuracy: 0.4278 - Precision: 0.9863 - Recall: 0.9566 - loss: 9.0860e-04 - val_AUC: 0.9919 - val_Accuracy: 0.4282 - val_Precision: 0.9910 - val_Recall: 0.9625 - val_loss: 7.6170e-04
# Epoch 11/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 45s 68ms/step - AUC: 0.9923 - Accuracy: 0.4293 - Precision: 0.9873 - Recall: 0.9593 - loss: 8.3847e-04 - val_AUC: 0.9921 - val_Accuracy: 0.4286 - val_Precision: 0.9912 - val_Recall: 0.9639 - val_loss: 7.3802e-04
# Epoch 12/12
# 661/661 ━━━━━━━━━━━━━━━━━━━━ 48s 72ms/step - AUC: 0.9929 - Accuracy: 0.4267 - Precision: 0.9884 - Recall: 0.9610 - loss: 7.6749e-04 - val_AUC: 0.9928 - val_Accuracy: 0.4286 - val_Precision: 0.9911 - val_Recall: 0.9646 - val_loss: 7.3579e-04

# %% [markdown]
# Tuning max sequence length hyperparameter

# %%
save_dir = '../models'
model.save(f'{save_dir}/dkt_model_pretrained.keras')

# %%
model.save(f'{save_dir}/dkt_model_pretrained.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
print("Dataset size:", df.shape[0])
print("Unique students:", df['user_id'].nunique())
print("Number of unique skills:", num_skills)
print("Top 5 skills:\n", df['skill_name_split'].explode().value_counts().head())
print("Number of unique question types:", num_question_types)
print("Question type distribution:\n", df['answer_type'].value_counts())
print("Overall correctness rate:", df['correct'].mean())
print("overlap_time: min", df['overlap_time'].min(), "max", df['overlap_time'].max())
print("hint_count: min", df['hint_count'].min(), "max", df['hint_count'].max())
print("attempt_count: min", df['attempt_count'].min(), "max", df['attempt_count'].max())
print("Avg seq len per student:", df.groupby('user_id').size().mean())
print("Max seq len per student:", df.groupby('user_id').size().max())
print("Min seq len per student:", df.groupby('user_id').size().min())
# Out:
# Dataset size: 549020
# Unique students: 6242
# Number of unique skills: 174
# Top 5 skills:
#  skill_name_split
# Pattern Finding                      26927
# Proportion                           22840
# Addition and Subtraction Integers    17707
# Probability of a Single Event        16672
# Substitution                         16113
# Name: count, dtype: int64
# Number of unique question types: 3
# Question type distribution:
#  answer_type
# choose_1     234369
# algebra      201179
# fill_in_1    113472
# Name: count, dtype: int64
# Overall correctness rate: 0.5735583403154711
# overlap_time: min 0.0 max 1.0
# hint_count: min 0.0 max 1.0
# attempt_count: min 0.0 max 1.0
# Avg seq len per student: 87.95578340275553
# Max seq len per student: 1036
# Min seq len per student: 10
